# %% [markdown]
# <font size = 8> Principal Component Analysis

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %%
def plot_vectors(vectors, colors):
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
# function to convert column of matrix to 1D vector: 
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:,clmn]).reshape(-1)

# %% [markdown]
# ***

# %%
# technique fro unlabled data

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# structure in unlabeled data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# norms

# %%
# orthogonal & identity matrices

# %%
# trace operator

# %% [markdown]
# ***

# %% [markdown]
# This PCA example code is adapted from [here](https://jupyter.brynmawr.edu/services/public/dblank/CS371%20Cognitive%20Science/2016-Fall/PCA.ipynb).

# %%
# import the iris dataset from sklearn

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
iris.data.shape
# Out:
# (150, 4)

# %%
# 150 roews, 4 colums

# %%
iris.get("feature_names")
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# 4 columns refer to 4 features

# %%
iris.data[0:6, :]

# just reviewing the first 6 rows
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4]])

# %% [markdown]
# ***

# %%
from sklearn.decomposition import PCA

# import PCA from sklearn decomposition module

# %%
pca = PCA(n_components=2)

# %%
# we are returning for just 2 components

# in order to plot them on x & y

# %%
# we are reducing 4 features to 2

# %% [markdown]
# ***

# %%
#fit the model

# %%
X = pca.fit_transform(iris.data)

# %%
X.shape
# Out:
# (150, 2)

# %%
X[0:6,:]
# Out:
# array([[-2.68412563,  0.31939725],
#        [-2.71414169, -0.17700123],
#        [-2.88899057, -0.14494943],
#        [-2.74534286, -0.31829898],
#        [-2.72871654,  0.32675451],
#        [-2.28085963,  0.74133045]])

# %%
_ = plt.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# ***

# %%
# the assumption thus far si that we are working with unlabeled data

# %%
# however, for the iris dataset, we do have labels

# %%
iris.target[0:6]
# Out:
# array([0, 0, 0, 0, 0, 0])

# %%
# ewe are not using the labels to predict

# rather to add color

# %%
unique_elements, counts_elements = np.unique(iris.target, return_counts=True)
np.asarray((unique_elements, counts_elements))
# Out:
# array([[ 0,  1,  2],
#        [50, 50, 50]])

# %%
# what the labeled data tells is that there are 50 each from 3 species each

# %%
list(iris.target_names)
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
_ = plt.scatter(X[:, 0], X[:, 1], c=iris.target)
