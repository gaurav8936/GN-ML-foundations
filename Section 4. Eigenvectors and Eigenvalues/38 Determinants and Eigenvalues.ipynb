# %% [markdown]
# <font size = 8> Determinants and Eigenvalues

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %%
def plot_vectors(vectors, colors):
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
# function to convert column of matrix to 1D vector: 
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:,clmn]).reshape(-1)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %%
X = np.array([[1, 2, 4], [2, -1, 3], [0, 5, 1]])

# %%
X
# Out:
# array([[ 1,  2,  4],
#        [ 2, -1,  3],
#        [ 0,  5,  1]])

# %%
np.linalg.det(X)
# Out:
# 19.999999999999996

# %%
# now compute the engenvalues

# %%
lambdas, V = np.linalg.eig(X)

# %%
V

# this is the matrix of eigen vectors
# Out:
# array([[-0.38021672,  0.80395279,  0.7014215 ],
#        [-0.59949826,  0.23387109,  0.47053617],
#        [ 0.704299  , -0.5467762 ,  0.53535371]])

# %%
lambdas

# this is a vector of eigenvalyes
# Out:
# array([-3.25599251, -1.13863631,  5.39462882])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# -3.25 X -1.13 * 5.39

# %%
-3.25 * -1.13 * 5.39
# Out:
# 19.794774999999994

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ie applying X to some tensor

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# Here's $|\text{det}(X)|$ in NumPy:

# %%
# Here is the absolute value

np.abs(np.linalg.det(X))
# Out:
# 19.999999999999996

# %% [markdown]
# Let's use a matrix $B$, which is composed of basis vectors, to explore the impact of applying matrices with varying $|\text{det}(X)|$ values:

# %%
B = np.array([[1, 0], [0, 1]])

# %%
B
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
plot_vectors([vectorfy(B, 0), vectorfy(B, 1)],
            ['lightblue', 'lightgreen'])
plt.xlim(-1, 3)
_ = plt.ylim(-1, 3)

# %%
# two basis vectors

# %%
# basis vectors are ortogonal and have unit norm (L2)

# %%
# this is also orthonormal

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# imagine a rectangle -- that is the volume

# %% [markdown]
# ***

# %% [markdown]
# ### Now see how volume changes after applying different matrices

# %%
N = np.array([[-4, 1], [-8, 2]])

# %%
N
# Out:
# array([[-4,  1],
#        [-8,  2]])

# %% [markdown]
# Let's start by applying the matrix $N$ to $B$, recalling from earlier that $N$ is singular:

# %%
# N is SINGULAR

# parallel lines

# cannot be inverted

#

# %%
np.linalg.det(N)
# Out:
# 0.0

# %%
# determinant is 0

# %%
# now apply N to B

# %%
NB = np.dot(N, B)

# %%
NB
# Out:
# array([[-4,  1],
#        [-8,  2]])

# %%
plot_vectors([vectorfy(B, 0), vectorfy(B, 1), vectorfy(NB, 0), vectorfy(NB, 1)],
            ['lightblue', 'lightgreen', 'blue', 'green'])
plt.xlim(-6, 6)
_ = plt.ylim(-9, 3)

# %%
# after applying the matrix N to B, the two vectors have been collapsed

# %%
# you will see the two new vectors in a straight line and oppositve each other

# no volume (in this case square area)

# %% [markdown]
# ***

# %%
# let us calculate eigenvalues

# %%
lambdas, V = np.linalg.eig(N)

# %%
lambdas
# Out:
# array([-2.,  0.])

# %%
# the product of th two values is 0

# %% [markdown]
# Aha! If any one of a matrix's eigenvalues is zero, then the product of the eigenvalues must be zero and the determinant must also be zero.

# %%
# this matches the determinant valyue of 0 (from above)

# %% [markdown]
# ***

# %% [markdown]
# Now let's try applying $I_2$ to $B$:

# %%
I = np.array([[1, 0], [0, 1]])

# %%
I
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
# determinant

# %%
np.linalg.det(I)
# Out:
# 1.0

# %%
# apply the matrix to B

# %%
IB = np.dot(I, B)

# %%
IB
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
plot_vectors([vectorfy(B, 0), vectorfy(B, 1), vectorfy(IB, 0), vectorfy(IB, 1)],
            ['lightblue', 'lightgreen', 'blue', 'green'])
plt.xlim(-1, 3)
_ = plt.ylim(-1, 3)

# %%
# because of the identity matrix, the basis vector have not changed

# %%
lambdas, V = np.linalg.eig(I)

# %%
lambdas
# Out:
# array([1., 1.])

# %%
# 1 X 1 = 1

# %%
# vectors retain the same volume as before

# %% [markdown]
# ***

# %%
# Applying matrix J

# %%
J = np.array([[-0.5, 0], [0, 2]])

# %%
J
# Out:
# array([[-0.5,  0. ],
#        [ 0. ,  2. ]])

# %%
# calculate determinant of J

# %%
np.linalg.det(J)
# Out:
# -1.0

# %%
np.abs(np.linalg.det(J))
# Out:
# 1.0

# %%
# absolute value = 1

# %%
# now apply J to B

# %%
JB = np.dot(J, B)

# %%
JB
# Out:
# array([[-0.5,  0. ],
#        [ 0. ,  2. ]])

# %%
plot_vectors([vectorfy(B, 0), vectorfy(B, 1), vectorfy(JB, 0), vectorfy(JB, 1)],
            ['lightblue', 'lightgreen', 'blue', 'green'])
plt.xlim(-1, 3)
_ = plt.ylim(-1, 3)

# %%
# notice that J does transform the two basis vectors

# %%
# becauase they remain on teh spans, they are eigenvectors

# %%
# calclate the eigenvalues

# %%
lambdas, V = np.linalg.eig(J)

# %%
lambdas
# Out:
# array([-0.5,  2. ])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color = red> even though shape has changed, the area is still the same (1)

# %%
# they retain the volume

# %% [markdown]
# ***

# %% [markdown]
# Finally, let's apply the matrix $D$, which scales vectors by doubling along both the $x$ and $y$ axes:

# %%
D = I*2

# %%
D
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
np.linalg.det(D)
# Out:
# 4.0

# %%
# now apply D to B

# %%
DB = np.dot(D, B)

# %%
DB
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
plot_vectors([vectorfy(B, 0), vectorfy(B, 1), vectorfy(DB, 0), vectorfy(DB, 1)],
            ['lightblue', 'lightgreen', 'blue', 'green'])
plt.xlim(-1, 3)
_ = plt.ylim(-1, 3)

# %%
# both basis vectors have doubled in length

# %%
# they are both eigenvectors -- they are on the same span

# %%
# now compyte the eigenvalues

lambdas, V = np.linalg.eig(D)

# %%
lambdas
# Out:
# array([2., 2.])
