# %% [markdown]
# <font size = 8> Determinants of Larger Matrices

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 4 rounds of recursion needed

# a selection of different 2X2 matrices

# then 3X3 matrices

# then 4X4 matrices

# finally 5X5 matrices

# %%
# starts with top left

# %%
# det(X 1,1) is the bottom 4X4 matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# det X 1,2 is also a 4X4 matrix which is

# %% [markdown]
# ![image.png](attachment:image.png), ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <font color = red> Notice the alternate + and -

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# becuase tgus value is not 0, it can be inverted

# %% [markdown]
# ***

# %%
X = np.array([[1, 2, 4], [2, -1, 3], [0, 5, 1]])

# %%
X
# Out:
# array([[ 1,  2,  4],
#        [ 2, -1,  3],
#        [ 0,  5,  1]])

# %%
np.linalg.det(X)
# Out:
# 19.999999999999996
