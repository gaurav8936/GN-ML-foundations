# %% [markdown]
# <font size = 8> Eigenvector and Eigenvalues Applications

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# equal scalilng

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# equal

# both eigen values are = k and non zero

# %%
# unequal scaling

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# horiontal shear

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# types of matrices

# this is out of scope

# %%
# positive definite

# %%
# positive semidefinite

# %%
# negative definite

# %%
# negative semidefinite

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# eigenfaces

# %%
# eigenvoices

# %%
# eigenfrequencies

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Reproduction number (how contagious a virus is)

# calculating R0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# singular value decomposition

# SVD

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# PCA - principal component analysis

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***
