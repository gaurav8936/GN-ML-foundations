# %% [markdown]
# <font size = 8> Intro to Differential Calculus

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %%
def plot_vectors(vectors, colors):
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
# function to convert column of matrix to 1D vector: 
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:,clmn]).reshape(-1)

# %% [markdown]
# ***

# %%
# mathematical study of continuous change

# differential calculus

# integral calculus

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# rates of change

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# tangent (slope of curve) is changing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# vehicle is stationary at this step

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Differential calculus can be used to calculate the slope of the line

# this is the DERIVATIVE

# %%
# slope is generally denoted as m

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# plotting speed

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# right side is a curve of speed

# %% [markdown]
# ### slope = speed

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# now we can do the opposite -- calculate teh slope bsed on speed

# %%
# this can also be got from differential calculus

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# flat like means acceleration is 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# in this case, slope m is change in speed / change in time

# %% [markdown]
# ### each of the two ways is a DERIVATIVE

# %%
# there is a third derivative -- not needed to explore now
