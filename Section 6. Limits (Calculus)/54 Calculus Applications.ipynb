# %% [markdown]
# <font size = 8> Calculus Applications

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %%
def plot_vectors(vectors, colors):
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
# function to convert column of matrix to 1D vector: 
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:,clmn]).reshape(-1)

# %% [markdown]
# ***

# %%
# applying calculs in the real world

# %% [markdown]
# # differential calculus

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# differential allows us to get the slope of a curve at a given time

# %%
# minimum or maximum of curves

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# example from deep learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# note the error keeps decreasing while accuracy is increasing

# %%
# so the gradient of cost is descendingo

# this is the biggest single topic to cover

# %%
# we maximize reward in reinforcement learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# at the beginning, the score isn't good

# %%
# however, we ascend the reward curve and maximize the points

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# in this case, the max is 200 and we come close to it

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# higher order derivatices

# recall we started with distance / time, and then evolved to speed / time which

###### a second order derivate is to have acceleration / time

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# accelration / time is an example of a higher order derivative

# %% [markdown]
# ***

# %% [markdown]
# # integral calculus

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# reciever operating characteristic

# used in binary classification models

# %%
# integral calculus is used to calculate the area under the curve

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# expectation of random variable is a widely used concept in machine learning
