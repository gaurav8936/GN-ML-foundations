# %% [markdown]
# <font size = 8> Calculus of the Infinitesimals

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %%
def plot_vectors(vectors, colors):
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
# function to convert column of matrix to 1D vector: 
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:,clmn]).reshape(-1)

# %% [markdown]
# ***

# %% [markdown]
# ### Applying the method of exhaustion to Differential Calculus

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# remember the slope of the curve

# %%
# approaching infinity, the curve is a straight line

# %%
x = np.linspace(-10, 10, 1000) # start, finish, n points

# %% [markdown]
# If $y = x^2 + 2x + 2$:

# %%
y = x**2 + 2*x + 2

# %%
fig, ax = plt.subplots()
_= ax.plot(x,y)

# %% [markdown]
# ***

# %%
# testing iwth my own

# %% [markdown]
# If  $y1 = x^3 + 2*x + 2:$

# %%
y1 = x**3 + 2*x + 2

# %%
fig, ax = plt.subplots()
_= ax.plot(x,y1)

# %% [markdown]
# ***

# %% [markdown]
# * There are no straight lines on the curve.
# * If we zoom in _infinitely_ close, however, we observe curves that _approach_ lines.
# * This enables us to find a slope $m$ (tangent) anywhere on the curve, including to identify where $m = 0$:

# %%
# if we zoom in infinitely, then curves approach lines

# %%
# this allows us to find the slope m(tangent) including when m = 0

# %% [markdown]
# ***

# %%
# now zoom into one section

# %%
fig, ax = plt.subplots()
ax.set_xlim([-2, -0])
ax.set_ylim([0,2])
_=ax.plot(x,y)

# %%
# zoom in further

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.5, -0.5])
ax.set_ylim([0.5, 1.5])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.1, -0.9])
ax.set_ylim([0.9, 1.1])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.01, -0.99])
ax.set_ylim([0.99, 1.01])
_ = ax.plot(x,y)

# %%
# this line is perfectly horizontal

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.001, -0.999])
ax.set_ylim([0.990, 1.001])
_ = ax.plot(x,y)
