# %% [markdown]
# <font size = 8> Exercises on Limits

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %%
def plot_vectors(vectors, colors):
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
# function to convert column of matrix to 1D vector: 
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:,clmn]).reshape(-1)

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# $$ \lim_{x \to \infty} \frac{25}{x} $$

# %%
def inf_fxn(my_x1):
    my_y1 = 25/my_x1
    return my_y1

# %%
x1 = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
y1 = inf_fxn(x1)

# %%
inf_fxn(1e3)

# 1e3 (scientific notation for 1000)
# Out:
# 0.025

# %%
inf_fxn(1e6)
# Out:
# 2.5e-05

# %%
# this is now really close to 0

# %% [markdown]
# ***

# %% [markdown]
# **Exercises:**
#
# Evaluate the limits below using techniques from the slides or above.
#
# 1. $$ \lim_{x \to 0} \frac{x^2-1}{x-1} $$
# 2. $$ \lim_{x \to -5} \frac{x^2-25}{x+5} $$
# 3. $$ \lim_{x \to 4} \frac{x^2 -2x -8}{x-4} $$
# 4. $$ \lim_{x \to -\infty} \frac{25}{x} $$
# 5. $$ \lim_{x \to 0} \frac{25}{x} $$

# %% [markdown]
# ***

# %% [markdown]
# 1. $$ \lim_{x \to 0} \frac{x^2-1}{x-1} $$

# %%
def my_fxn2(my_x2):
    my_y2 = (my_x2**2 - 1) / (my_x2 - 1)
    return my_y2

# %%
x2 = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
y2 = my_fxn2(x2)

# %%
fig, ax = plt.subplots()
plt.axvline(x2=0, color='lightgray')
plt.axhline(y2=0, color='lightgray')
_ = ax.plot(x2,y2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 fig, ax = plt.subplots()
# ----> 2 plt.axvline(x2=0, color='lightgray')
#       3 plt.axhline(y2=0, color='lightgray')
#       4 _ = ax.plot(x2,y2)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2373, in axvline(x, ymin, ymax, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.axvline)
#    2372 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2373     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:804, in Axes.axvline(self, x, ymin, ymax, **kwargs)
#     801 scalex = (xx < xmin) or (xx > xmax)
#     803 trans = self.get_xaxis_transform(which='grid')
# --> 804 l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     805 self.add_line(l)
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# right handed limit has a plus (+) sign

# as we approach 0 from the left, you have a minus (-) sign

# %% [markdown]
# ***

# %% [markdown]
# # just testing

# %% [markdown]
# Let's bring back our ol' buddy $y = x^2 + 2x + 2$:

# %%
x3 = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
y3 = my_fxn3(x3)

# %%
def my_func3(my_x3):
    my_y3 = (my_x3)**2 + 2*(my_x3) + 2
    return my_y3

# %%
fig, ax = plt.subplots()
plt.axvline(x3=0, color='lightgray')
plt.axhline(y3=0, color='lightgray')
_ = ax.plot(x3,y3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 fig, ax = plt.subplots()
# ----> 2 plt.axvline(x3=0, color='lightgray')
#       3 plt.axhline(y3=0, color='lightgray')
#       4 _ = ax.plot(x3,y3)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2373, in axvline(x, ymin, ymax, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.axvline)
#    2372 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2373     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:804, in Axes.axvline(self, x, ymin, ymax, **kwargs)
#     801 scalex = (xx < xmin) or (xx > xmax)
#     803 trans = self.get_xaxis_transform(which='grid')
# --> 804 l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     805 self.add_line(l)
# ...

# %% [markdown]
# ***

# %%
def my_func(my_x):
    my_y = ((my_x)**2 -1) / ((my_x) - 1)
    return my_y

# %%
x = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
y = my_func(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
_ = ax.plot(x,y)

# %% [markdown]
# ***

# %%
def my_func1(my_x1):
    my_y1 = ((my_x1)**2 -1) / ((my_x1) - 1)
    return my_y1

# %%
x1 = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
y1 = my_func(x1)

# %%
fig, ax = plt.subplots()
plt.axvline(x1=0, color='lightgray')
plt.axhline(y1=0, color='lightgray')
_ = ax.plot(x1,y1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 fig, ax = plt.subplots()
# ----> 2 plt.axvline(x1=0, color='lightgray')
#       3 plt.axhline(y1=0, color='lightgray')
#       4 _ = ax.plot(x1,y1)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2373, in axvline(x, ymin, ymax, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.axvline)
#    2372 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2373     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:804, in Axes.axvline(self, x, ymin, ymax, **kwargs)
#     801 scalex = (xx < xmin) or (xx > xmax)
#     803 trans = self.get_xaxis_transform(which='grid')
# --> 804 l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     805 self.add_line(l)
# ...
