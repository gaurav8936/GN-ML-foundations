# %% [markdown]
# <font size = 8> Dot Product

# %% [markdown]
# ***

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
X = np.array([[25, 2], [5, 26], [3, 7]])

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X[:, 0]
# Out:
# array([25,  5,  3])

# %% [markdown]
# ***

# %% [markdown]
# ## PyTorch

# %%
import torch

# %%
X_pt = torch.tensor([[25, 2], [5, 26], [3, 7]])

# %%
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %% [markdown]
# ***

# %% [markdown]
# ## TensorFlow

# %%
import tensorflow as tf

# %%
X_tf = tf.Variable([[25, 2], [5, 26], [3, 7]])

# %%
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### NUMPY

# %%
x = np.array([25, 2, 5])

# %%
y = np.array([0, 1, 2])

# %%
x
# Out:
# array([25,  2,  5])

# %%
y
# Out:
# array([0, 1, 2])

# %%
# math

25*0 + 2*1 + 5*2
# Out:
# 12

# %%
np.dot(x,y)
# Out:
# 12

# %% [markdown]
# ### PyTorch

# %%
x_pt = torch.tensor([25, 2, 5])

# %%
y_pt = torch.tensor([0, 1, 2])

# %%
torch.dot(x_pt, y_pt)
# Out:
# tensor(12)

# %%
# Remember the above is not correct

# for torch, you will need to pass FLOAT values

# %%
torch.dot(torch.tensor([25,2,5.]), torch.tensor([0,1,2.]))
# Out:
# tensor(12.)

# %%
# just adding a decimal point to one of the values will do

# %% [markdown]
# ***

# %% [markdown]
# ### TensorFlow

# %%
x_tf = tf.Variable([25,2,5])

# %%
y_tf = tf.Variable([0,1,2])

# %%
# this is a multi-step process in TensorFlow

# %%
tf.reduce_sum(tf.multiply(x_tf, y_tf))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=12>
