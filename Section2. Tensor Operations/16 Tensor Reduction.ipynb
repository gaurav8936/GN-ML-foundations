# %% [markdown]
# <font size = 8> Tensor Reduction

# %% [markdown]
# ***

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
X = np.array([[25, 2], [5, 26], [3, 7]])

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X[:, 0]
# Out:
# array([25,  5,  3])

# %% [markdown]
# ***

# %% [markdown]
# ## PyTorch

# %%
import torch

# %%
X_pt = torch.tensor([[25, 2], [5, 26], [3, 7]])

# %%
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %% [markdown]
# ***

# %% [markdown]
# ## TensorFlow

# %%
import tensorflow as tf

# %%
X_tf = tf.Variable([[25, 2], [5, 26], [3, 7]])

# %%
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %% [markdown]
# ***

# %% [markdown]
# <font size = 8> Reduction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Numpy

X.sum()
# Out:
# 68

# %%
# pytorch
torch.sum(X_pt)
# Out:
# tensor(68)

# %%
# Tensorflow

tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=68>

# %% [markdown]
# ***

# %%
# calculate a reduction acvross only one dimention

# %%
# Python
# sum by column

X.sum(axis=0)
# Out:
# array([33, 35])

# %%
# Python
# Sum across rows

X.sum(axis = 1)
# Out:
# array([27, 31, 10])

# %% [markdown]
# ***

# %%
# Pytorch

torch.sum(X_pt, 0)
# Out:
# tensor([33, 35])

# %%
torch.sum(X_pt, 1)
# Out:
# tensor([27, 31, 10])

# %% [markdown]
# ***

# %%
# TensorFlow

tf.reduce_sum(X_tf, 0)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([33, 35], dtype=int32)>

# %%
# TensorFlow
# Sum across rows

tf.reduce_sum(X_tf, 1)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([27, 31, 10], dtype=int32)>

# %%
# notice the numpy array (above)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)
