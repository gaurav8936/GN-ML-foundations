# %% [markdown]
# <font size = 8> Norms and Unit Vectors

# %%
# so far, we have seen Vectors as being a point in space

# Now, we will look at vectors having magnitude and direction in space

# %%
# Norms quantify vector magnitude

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# x1,x2 represents a point in space thus far

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# However, we can also view vectors as having a magnitude (length)

# %% [markdown]
# # L2 Norm

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# BOLD x representing the vector

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Euclidean distance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# most common -- denoted without even the subscript 2

# %% [markdown]
# ***

# %%
import numpy as np

# %%
# x = 25

y = 3

# %%
x = np.array([25, 2, 5])

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)**(1/2)
# Out:
# 25.573423705088842

# %% [markdown]
# ### $L^2$ Norm

# %%
(25**2 + 2**2 + 5**2)**(1/2)
# Out:
# 25.573423705088842

# %% [markdown]
# ***

# %%
# you can also use numpy's linear algebra method to get this

np.linalg.norm(x)
# Out:
# 25.573423705088842

# %%
# this is a 3 dimensional space

# from (0,0,0) to (25,2,5)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# the L2 norm (orange line) == 1

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# takes absolute value of every element

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### $L^1$ Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.abs(25) + np.abs(2) + np.abs(5)
# Out:
# 32

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# like the L2 norm, but there is no square root

# %%
x
# Out:
# array([25,  2,  5])

# %%
l2norm = (25**2 + 2**2 + 5**2)

# %%
l2norm
# Out:
# 654

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.dot(x,x)
# Out:
# 654

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Max Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
maxnorm = np.max([np.abs(25), np.abs(2), np.abs(5)])

# %%
maxnorm
# Out:
# 25

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# this is seen frequently in machine learning

# L1 and L2 penalties of regression
