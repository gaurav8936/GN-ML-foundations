# %% [markdown]
# <font size = 8> Basis, Orthogonal and Orthonormal Vectors

# %% [markdown]
# ## Basis Vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# can be scaled to any vector

# %%
# usually use unit vectors on the axis

# %%
# unit vector i (1, 0)

# unit vector j (0,1)

# %% [markdown]
# ### vector V is got by scaling unit vectors i & j

# %% [markdown]
# ***

# %% [markdown]
# ### Orthogonal Vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
i = np.array([1,0])

# %%
i
# Out:
# array([1, 0])

# %%
j = np.array([0,1])

# %%
j
# Out:
# array([0, 1])

# %%
# Get the DOT product

# %%
np.dot(i, j)
# Out:
# 0
