# %% [markdown]
# <font size = 6> Finding the area under the ROC curve

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %%
from scipy.integrate import quad # "quadrature" = numerical integration 
# (as opposed to symbolic)

# %% [markdown]
# .DS_Store files

# %% [markdown]
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When we don't have a function but we do have $(x, y)$ coordinates, we can use the scikit-learn library's `auc()` method, which uses a numerical approach (the [trapezoidal rule](https://en.wikipedia.org/wiki/Trapezoidal_rule)) to find the area under the curve described by the coordinates:

# %%
# all the integration involved so far involved a function

# %%
from sklearn.metrics import auc

# %%
# however, for the ROC we don't really have a function

# %%
# However, we have the coordinates

# %%
# means we can use the trapeoidal method to find a numerical way to get the ROC

# %% [markdown]
# From the slides, the $(x, y)$ coordinates of our hot dog-detecting ROC curve are:
#
# * (0, 0)
# * (0, 0.5)
# * (0.5, 0.5)
# * (0.5, 1)
# * (1, 1)

# %%
xs = [0,0,0.5, 0.5, 1]

# %%
ys = [0,0.5, 0.5, 1,1]

# %%
auc(xs, ys)
# Out:
# 0.75
