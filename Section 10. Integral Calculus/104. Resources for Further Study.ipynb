# %% [markdown]
# <font size = 6> Resources for Further Study

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %%
from scipy.integrate import quad # "quadrature" = numerical integration 
# (as opposed to symbolic)

# %%
from sklearn.metrics import auc

# %% [markdown]
# .DS_Store files

# %% [markdown]
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# eblue1brown on youtube

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %%
# binary classification

# %%
# the confusion matrix

# %%
# the ROC curve

# %%
# Calculating integrals manually

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# partial derivatives & Integrals

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
