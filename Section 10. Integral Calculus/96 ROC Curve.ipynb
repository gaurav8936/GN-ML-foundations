# %% [markdown]
# <font size = 6> Receiver Operating Characteristc (ROC) Curve

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %%
# column y is the true state of the world

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for case 1 (0), the yhat is .3 -- so algoright has the least confidence thete is a hotdog
# in the image

# %% [markdown]
# ### Receiver Operating Characteristic

# %%
# at or below (so, below, .3 is consider .3 or below)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# remember the .3 threshold

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# anything above .5 is a hot dog, anything below .5 is not a hot dog

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # True Positive Rate

# %%
# true positive rate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # False Positive Rate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %%
# we now plot this on a curve

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## we add extra coordinates at 0,0 and 1,1

# %%
# the goal is to fill in the curve

# %%
# the ROC for above is 0.75

# %% [markdown]
# ![image.png](attachment:image.png)
