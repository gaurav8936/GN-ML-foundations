# %% [markdown]
# <font size = 8> What Integral Calculus Is

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# you can get the total distance traveled

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# receiver operating characteristic

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# probability theory's expectation of random variable -- used in deep learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# the rectangle stand for delta x -- smaller it gets, ti approaches a width of zero

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dx indicates slide width delta x approach zero width
# Out:
#   Input In [6]
#     dx indicates slide width delta x approach zero width
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)
