# %% [markdown]
# <font size = 8> Binary Classification

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %%
# input x

# outcome y

# %%
# learn some function that uses input x to estimate y

# %% [markdown]
# ## Supervised Learning Types

# %% [markdown]
# ***

# %%
# Regression

# Classification
    # Multinomial
    
    # Binomial

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# binomial
    # moview reviews
    # image - hot dog / not hot dog

# %%
# threshold

# %% [markdown]
# # Threshold

# %%
# default is 0.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# the second model is more confident on the right (hot dog preduction)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#  Solution to the single metric is the ROC AUC
