# %% [markdown]
# <font size = 7, color = teal> Definite Integral Exercise

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %%
from scipy.integrate import quad # "quadrature" = numerical integration 
# (as opposed to symbolic)

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def h(x):
    return 2*x

# %%
quad(h,3,4)
# Out:
# (7.0, 7.771561172376096e-14)

# %%
# note the function is the original on e-- not the broken down integral
# breaking it down is the function of the quad function
