# %% [markdown]
# <font size = 6> Definite Integrals with Python

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %%
from scipy.integrate import quad # "quadrature" = numerical integration 
# (as opposed to symbolic)

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the slides: $$ \int_1^2 \frac{x}{2} dx = \frac{3}{4} $$

# %%
# quadrature method from the scipy library for solving integrals

# %% [markdown]
# ## How Numerical Integration works - Research for later

# %%
def g(x):
    return x/2

# %%
quad(g,1,2)
# Out:
# (0.75, 8.326672684688674e-15)

# %%
# the second output of quad is an estimate of this error in this integral
# essentially zero
