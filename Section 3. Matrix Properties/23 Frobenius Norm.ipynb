# %% [markdown]
# <font size = 8> Frobenius Norm

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# i rows and j columns

# %%
# we square each element before summing it up

# %%
# This is similar to the L2 norm for a vector

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %%
import numpy as np

# %%
X = np.array([[1,2], [3,4]])

# %%
X
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
(1**2 + 2**2 + 3**2 + 4**2)**(1/2)
# Out:
# 5.477225575051661

# %%
np.linalg.norm(X) 

# same function as the L2 norm for vectors
# Out:
# 5.477225575051661

# %% [markdown]
# ***

# %%
import torch

# %%
X_pt = torch.tensor([[1,2], [3,4]])

# %%
X_pt
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
torch.norm(X_pt)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 torch.norm(X_pt)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/functional.py:1448, in norm(input, p, dim, keepdim, out, dtype)
#    1446 if isinstance(p, str):
#    1447     if p == "fro":
# -> 1448         return _VF.frobenius_norm(input, dim=(), keepdim=keepdim)
#    1449 if not isinstance(p, str):
#    1450     _dim = [i for i in range(ndim)]  # noqa: C416 TODO: rewrite as list(range(m))
#
# RuntimeError: norm(): input dtype should be either floating point or complex. Got Long instead.

# %%
X2_pt = torch.tensor([[1,2], [3,4.]])

# torch needs float

# %%
torch.norm(X2_pt)
# Out:
# tensor(5.4772)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %%
import tensorflow as tf

# %%
X_tf = tf.Variable([[1,2], [3,4.]])

# %%
tf.norm(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=5.477226>

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
x = np.array([25, 2, 5])

# %%
y = np.array([0, 1, 2])

# %% [markdown]
# ***

# %%
X = np.array([[25, 2], [5, 26], [3, 7]])

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X[:, 0]
# Out:
# array([25,  5,  3])

# %% [markdown]
# ***

# %% [markdown]
# ## PyTorch

# %%
import torch

# %%
x_pt = torch.tensor([25, 2, 5])

# %%
y_pt = torch.tensor([0, 1, 2])

# %% [markdown]
# ***

# %%
X_pt = torch.tensor([[25, 2], [5, 26], [3, 7]])

# %%
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %% [markdown]
# ***

# %% [markdown]
# ## TensorFlow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable([25,2,5])

# %%
y_tf = tf.Variable([0,1,2])

# %% [markdown]
# ***

# %%
X_tf = tf.Variable([[25, 2], [5, 26], [3, 7]])

# %%
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %% [markdown]
# ***

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt
