# %% [markdown]
# <font size = 6> Higher Order Partial Derivatives

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %%
# second order partial derivatives

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# deld / delt = slope m = speed

# %%
# so, speed is the first order derivatices

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# this is an example of a second order derivative

# %%
# that is accelration --  del speed / del time

# %%
# higher order derivatives are needed to accelrate gradient descent

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# first order partial derivatices

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# we can now get the second order derivatices

# %% [markdown]
# ## Unmixed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Mixed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for mxed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)
