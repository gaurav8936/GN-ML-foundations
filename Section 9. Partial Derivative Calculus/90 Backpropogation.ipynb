# %% [markdown]
# <font size = 8> Backpropogation

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# this si about the chain rule of partial derivative of cost

# %%
# backpropogation is the process of calculating the partial derivate of cost wrt each 
# parameter
