# %% [markdown]
# <font size = 6> Chain Rule for Partial Derivatives

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %% [markdown]
# .DS_Store files
#
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %%
def plot_vectors(vectors, colors):
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
# function to convert column of matrix to 1D vector: 
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:,clmn]).reshape(-1)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is the chain rule for FULL DERIVATIVES
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# in this case the full derivative is the same as the partial derivative

# there is just one variable (x)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# u is a multi variate function

# %%
# function g is nested inside function g

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# dy/dx = dy/du * du/dx

# dy/dz = dy/du * du/dz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# dy/dx = (dy/du * du/dx) + (dy/dv * dv/dx)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# dy/dz = dy/..

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# u is itself a function of many inputs

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# dy/dxi = (dy/du1 * du1/dxi) + (dy/du2 * du2/dxi) + (dy/du3 * du3/dxi)... ()
