# %% [markdown]
# <font size = 8> Probabibility & Information Theory

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries & Stuff

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import math # for constant pi

# %%
from scipy.integrate import quad # "quadrature" = numerical integration 
# (as opposed to symbolic)

# %%
from sklearn.metrics import auc

# %% [markdown]
# .DS_Store files

# %% [markdown]
# find .  -name ".DS_Store" -depth -exec rm {} \;

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# orandom variables - single most important concept in probability theory

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# measures of central tendancy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
